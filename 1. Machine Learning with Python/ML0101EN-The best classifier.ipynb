# %% [markdown]
# <a href="https://www.bigdatauniversity.com"><img src="https://ibm.box.com/shared/static/cw2c7r3o20w9zn8gkecaeyjhgw3xdgbj.png" width="400" align="center"></a>
#
# <h1 align="center"><font size="5">Classification with Python</font></h1>

# %% [markdown]
# In this notebook we try to practice all the classification algorithms that we learned in this course.
#
# We load a dataset using Pandas library, and apply the following algorithms, and find the best one for this specific dataset by accuracy evaluation methods.
#
# Lets first load required libraries:

# %% [markdown]
# # Note: Please do not run the notebook. The Report is at most bottom in Markdown cell. Thanks.

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import jaccard_score
#from sklearn.metrics import jaccard_similarity_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score
# %matplotlib inline
from pycaret.classification import *

# %% [markdown]
# ### About dataset

# %% [markdown]
# This dataset is about past loans. The __Loan_train.csv__ data set includes details of 346 customers whose loan are already paid off or defaulted. It includes following fields:
#
# | Field          | Description                                                                           |
# |----------------|---------------------------------------------------------------------------------------|
# | Loan_status    | Whether a loan is paid off on in collection                                           |
# | Principal      | Basic principal loan amount at the                                                    |
# | Terms          | Origination terms which can be weekly (7 days), biweekly, and monthly payoff schedule |
# | Effective_date | When the loan got originated and took effects                                         |
# | Due_date       | Since it’s one-time payoff schedule, each loan has one single due date                |
# | Age            | Age of applicant                                                                      |
# | Education      | Education of applicant                                                                |
# | Gender         | The gender of applicant                                                               |

# %% [markdown]
# Lets download the dataset

# %%
#!wget -O loan_train.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_train.csv

# %% [markdown]
# ### Load Data From CSV File

# %%
df = pd.read_csv('loantrain.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30       9/8/2016
# 1           2             2     PAIDOFF       1000     30       9/8/2016
# 2           3             3     PAIDOFF       1000     15       9/8/2016
# 3           4             4     PAIDOFF       1000     30       9/9/2016
# 4           6             6     PAIDOFF       1000     30       9/9/2016
#
#     due_date  age             education  Gender
# 0  10/7/2016   45  High School or Below    male
# 1  10/7/2016   33              Bechalor  female
# 2  9/22/2016   27               college    male
# 3  10/8/2016   28               college  female
# 4  10/8/2016   29               college    male

# %%
df.shape
# Out:
# (346, 10)

# %% [markdown]
# ### Convert to date time object

# %%
df['due_date'] = pd.to_datetime(df['due_date'])
df['effective_date'] = pd.to_datetime(df['effective_date'])
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender
# 0 2016-10-07   45  High School or Below    male
# 1 2016-10-07   33              Bechalor  female
# 2 2016-09-22   27               college    male
# 3 2016-10-08   28               college  female
# 4 2016-10-08   29               college    male

# %% [markdown]
# # Data visualization and pre-processing

# %% [markdown]
# Let’s see how many of each class is in our data set

# %%
df['loan_status'].value_counts()
# Out:
# PAIDOFF       260
# COLLECTION     86
# Name: loan_status, dtype: int64

# %% [markdown]
# 260 people have paid off the loan on time while 86 have gone into collection

# %% [markdown]
# Lets plot some columns to underestand data better:

# %%
# notice: installing seaborn might takes a few minutes
#!conda install -c anaconda seaborn -y

# %%
import seaborn as sns

bins = np.linspace(df.Principal.min(), df.Principal.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'Principal', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %%
bins = np.linspace(df.age.min(), df.age.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'age', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %% [markdown]
# # Pre-processing:  Feature selection/extraction

# %% [markdown]
# ### Lets look at the day of the week people get the loan

# %%
df['dayofweek'] = df['effective_date'].dt.dayofweek
bins = np.linspace(df.dayofweek.min(), df.dayofweek.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'dayofweek', bins=bins, ec="k")
g.axes[-1].legend()
plt.show()

# %% [markdown]
# We see that people who get the loan at the end of the week dont pay it off, so lets use Feature binarization to set a threshold values less then day 4

# %%
df['weekend'] = df['dayofweek'].apply(lambda x: 1 if (x>3)  else 0)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below    male          3        0
# 1 2016-10-07   33              Bechalor  female          3        0
# 2 2016-09-22   27               college    male          3        0
# 3 2016-10-08   28               college  female          4        1
# 4 2016-10-08   29               college    male          4        1

# %% [markdown]
# ## Convert Categorical features to numerical values

# %% [markdown]
# Lets look at gender:

# %%
df.groupby(['Gender'])['loan_status'].value_counts(normalize=True)
# Out:
# Gender  loan_status
# female  PAIDOFF        0.865385
#         COLLECTION     0.134615
# male    PAIDOFF        0.731293
#         COLLECTION     0.268707
# Name: loan_status, dtype: float64

# %% [markdown]
# 86 % of female pay there loans while only 73 % of males pay there loan

# %% [markdown]
# Lets convert male to 0 and female to 1:

# %%
df['Gender'].replace(to_replace=['male','female'], value=[0,1],inplace=True)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below       0          3        0
# 1 2016-10-07   33              Bechalor       1          3        0
# 2 2016-09-22   27               college       0          3        0
# 3 2016-10-08   28               college       1          4        1
# 4 2016-10-08   29               college       0          4        1

# %% [markdown]
# ## One Hot Encoding
# #### How about education?

# %%
df.groupby(['education'])['loan_status'].value_counts(normalize=True)
# Out:
# education             loan_status
# Bechalor              PAIDOFF        0.750000
#                       COLLECTION     0.250000
# High School or Below  PAIDOFF        0.741722
#                       COLLECTION     0.258278
# Master or Above       COLLECTION     0.500000
#                       PAIDOFF        0.500000
# college               PAIDOFF        0.765101
#                       COLLECTION     0.234899
# Name: loan_status, dtype: float64

# %% [markdown]
# #### Feature before One Hot Encoding

# %%
df[['Principal','terms','age','Gender','education']].head()
# Out:
#    Principal  terms  age  Gender             education
# 0       1000     30   45       0  High School or Below
# 1       1000     30   33       1              Bechalor
# 2       1000     15   27       0               college
# 3       1000     30   28       1               college
# 4       1000     30   29       0               college

# %% [markdown]
# #### Use one hot encoding technique to conver categorical varables to binary variables and append them to the feature Data Frame

# %%
Feature = df[['Principal','terms','age','Gender','weekend']]
Feature = pd.concat([Feature,pd.get_dummies(df['education'])], axis=1)
Feature.drop(['Master or Above'], axis = 1,inplace=True)
Feature.head()
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %% [markdown]
# ### Feature selection

# %% [markdown]
# Lets define feature sets, X:

# %%
X = Feature
X[0:5]
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %% [markdown]
# What are our lables?

# %%
y = df['loan_status'].values
y[0:5]
# Out:
# array(['PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'],
#       dtype=object)

# %% [markdown]
# ### Create new dataframe

# %%
new_df = pd.concat([Feature,df['loan_status']],axis=1)

# %%
new_df
# Out:
#      Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0         1000     30   45       0        0         0                     1
# 1         1000     30   33       1        0         1                     0
# 2         1000     15   27       0        0         0                     0
# 3         1000     30   28       1        1         0                     0
# 4         1000     30   29       0        1         0                     0
# 5         1000     30   36       0        1         0                     0
# 6         1000     30   28       0        1         0                     0
# 7          800     15   26       0        1         0                     0
# 8          300      7   29       0        1         0                     0
# 9         1000     15   39       0        1         0                     1
# 10        1000     30   26       0        1         0                     0
# 11         900      7   26       1        1         0                     0
# 12        1000      7   27       0        1         0                     1
# 13         800     15   26       0        1         0                     0
# 14        1000     30   40       0        1         0                     1
# 15        1000     15   32       0        1         0                     1
# 326       1000     30   32       0        1         0                     0
# 327       1000     30   25       0        1         0                     1
# 328        800     15   35       0        1         0                     1
# 329       1000     15   30       0        1         1                     0
# 330       1000     30   26       0        1         0                     1
# 331       1000     30   29       0        1         0                     1
# 332       1000     30   26       0        1         0                     1
# 333        800     15   46       0        1         0                     1
# 334       1000     30   36       0        1         0                     1
# 335       1000     15   38       0        1         1                     0
# 336       1000     15   32       0        1         0                     1
# 337       1000     15   30       0        1         0                     0
# 338        800     15   35       0        1         0                     1
# 339       1000     30   29       1        1         0                     0
# 340       1000     30   26       0        1         0                     0
# 341        800     15   32       0        1         0                     1
# 342       1000     30   25       0        1         0                     1
# 343        800     15   39       0        0         0                     0
# 344       1000     30   28       0        0         0                     0
# 345       1000     30   26       0        0         0                     0
#
#      college loan_status
# 0          0     PAIDOFF
# 1          0     PAIDOFF
# 2          1     PAIDOFF
# 3          1     PAIDOFF
# 4          1     PAIDOFF
# 5          1     PAIDOFF
# 6          1     PAIDOFF
# 7          1     PAIDOFF
# 8          1     PAIDOFF
# 9          0     PAIDOFF
# 10         1     PAIDOFF
# 11         1     PAIDOFF
# 12         0     PAIDOFF
# 13         1     PAIDOFF
# 14         0     PAIDOFF
# 15         0     PAIDOFF
# 16         0     PAIDOFF
# 17         1     PAIDOFF
# 18         1     PAIDOFF
# 19         0     PAIDOFF
# 20         1     PAIDOFF
# 21         0     PAIDOFF
# 22         0     PAIDOFF
# 23         0     PAIDOFF
# 24         1     PAIDOFF
# 25         1     PAIDOFF
# 26         0     PAIDOFF
# 27         1     PAIDOFF
# 28         1     PAIDOFF
# 29         1     PAIDOFF
# 30         1     PAIDOFF
# 31         0     PAIDOFF
# 32         0     PAIDOFF
# 33         1     PAIDOFF
# 34         1     PAIDOFF
# 35         0     PAIDOFF
# 36         1     PAIDOFF
# 37         0     PAIDOFF
# 38         0     PAIDOFF
# 39         0     PAIDOFF
# 40         1     PAIDOFF
# 41         0     PAIDOFF
# 42         0     PAIDOFF
# 43         0     PAIDOFF
# 44         0     PAIDOFF
# 45         0     PAIDOFF
# 46         1     PAIDOFF
# 47         0     PAIDOFF
# 48         0     PAIDOFF
# 49         0     PAIDOFF
# 50         0     PAIDOFF
# 51         0     PAIDOFF
# 52         0     PAIDOFF
# 53         1     PAIDOFF
# 54         1     PAIDOFF
# 55         0     PAIDOFF
# 56         0     PAIDOFF
# 57         0     PAIDOFF
# 58         1     PAIDOFF
# 59         0     PAIDOFF
# 60         0     PAIDOFF
# 61         1     PAIDOFF
# 62         1     PAIDOFF
# 63         0     PAIDOFF
# 64         1     PAIDOFF
# 65         0     PAIDOFF
# 66         0     PAIDOFF
# 67         1     PAIDOFF
# 68         1     PAIDOFF
# 69         1     PAIDOFF
# 70         0     PAIDOFF
# 71         1     PAIDOFF
# 72         0     PAIDOFF
# 73         1     PAIDOFF
# 74         0     PAIDOFF
# 75         0     PAIDOFF
# 76         0     PAIDOFF
# 77         1     PAIDOFF
# 78         1     PAIDOFF
# 79         0     PAIDOFF
# 80         0     PAIDOFF
# 81         1     PAIDOFF
# 82         1     PAIDOFF
# 83         0     PAIDOFF
# 84         1     PAIDOFF
# 85         0     PAIDOFF
# 86         0     PAIDOFF
# 87         1     PAIDOFF
# 88         1     PAIDOFF
# 89         1     PAIDOFF
# 90         1     PAIDOFF
# 91         1     PAIDOFF
# 92         1     PAIDOFF
# 93         1     PAIDOFF
# 94         0     PAIDOFF
# 95         1     PAIDOFF
# 96         0     PAIDOFF
# 97         0     PAIDOFF
# 98         1     PAIDOFF
# 99         1     PAIDOFF
# 100        0     PAIDOFF
# 101        1     PAIDOFF
# 102        1     PAIDOFF
# 103        1     PAIDOFF
# 104        1     PAIDOFF
# 105        0     PAIDOFF
# 106        0     PAIDOFF
# 107        0     PAIDOFF
# 108        0     PAIDOFF
# 109        0     PAIDOFF
# 110        0     PAIDOFF
# 111        0     PAIDOFF
# 112        1     PAIDOFF
# 113        1     PAIDOFF
# 114        0     PAIDOFF
# 115        0     PAIDOFF
# 116        1     PAIDOFF
# 117        0     PAIDOFF
# 118        0     PAIDOFF
# 119        0     PAIDOFF
# 120        1     PAIDOFF
# 121        1     PAIDOFF
# 122        0     PAIDOFF
# 123        1     PAIDOFF
# 124        1     PAIDOFF
# 125        0     PAIDOFF
# 126        0     PAIDOFF
# 127        1     PAIDOFF
# 128        1     PAIDOFF
# 129        1     PAIDOFF
# 130        1     PAIDOFF
# 131        0     PAIDOFF
# 132        0     PAIDOFF
# 133        1     PAIDOFF
# 134        0     PAIDOFF
# 135        0     PAIDOFF
# 136        0     PAIDOFF
# 137        0     PAIDOFF
# 138        1     PAIDOFF
# 139        0     PAIDOFF
# 140        0     PAIDOFF
# 141        1     PAIDOFF
# 142        0     PAIDOFF
# 143        0     PAIDOFF
# 144        1     PAIDOFF
# 145        0     PAIDOFF
# 146        1     PAIDOFF
# 147        0     PAIDOFF
# 148        1     PAIDOFF
# 149        0     PAIDOFF
# 150        1     PAIDOFF
# 151        0     PAIDOFF
# 152        0     PAIDOFF
# 153        0     PAIDOFF
# 154        0     PAIDOFF
# 155        0     PAIDOFF
# 156        0     PAIDOFF
# 157        0     PAIDOFF
# 158        0     PAIDOFF
# 159        1     PAIDOFF
# 160        1     PAIDOFF
# 161        1     PAIDOFF
# 162        0     PAIDOFF
# 163        0     PAIDOFF
# 164        0     PAIDOFF
# 165        1     PAIDOFF
# 166        1     PAIDOFF
# 167        1     PAIDOFF
# 168        0     PAIDOFF
# 169        1     PAIDOFF
# 170        0     PAIDOFF
# 171        1     PAIDOFF
# 172        1     PAIDOFF
# 173        0     PAIDOFF
# 174        1     PAIDOFF
# 175        1     PAIDOFF
# 176        0     PAIDOFF
# 177        0     PAIDOFF
# 178        0     PAIDOFF
# 179        0     PAIDOFF
# 180        0     PAIDOFF
# 181        0     PAIDOFF
# 182        0     PAIDOFF
# 183        1     PAIDOFF
# 184        0     PAIDOFF
# 185        0     PAIDOFF
# 186        0     PAIDOFF
# 187        0     PAIDOFF
# 188        1     PAIDOFF
# 189        1     PAIDOFF
# 190        0     PAIDOFF
# 191        0     PAIDOFF
# 192        0     PAIDOFF
# 193        0     PAIDOFF
# 194        0     PAIDOFF
# 195        0     PAIDOFF
# 196        1     PAIDOFF
# 197        1     PAIDOFF
# 198        1     PAIDOFF
# 199        1     PAIDOFF
# 200        0     PAIDOFF
# 201        0     PAIDOFF
# 202        0     PAIDOFF
# 203        0     PAIDOFF
# 204        1     PAIDOFF
# 205        0     PAIDOFF
# 206        0     PAIDOFF
# 207        0     PAIDOFF
# 208        0     PAIDOFF
# 209        1     PAIDOFF
# 210        0     PAIDOFF
# 211        1     PAIDOFF
# 212        0     PAIDOFF
# 213        0     PAIDOFF
# 214        0     PAIDOFF
# 215        1     PAIDOFF
# 216        0     PAIDOFF
# 217        1     PAIDOFF
# 218        1     PAIDOFF
# 219        1     PAIDOFF
# 220        1     PAIDOFF
# 221        1     PAIDOFF
# 222        0     PAIDOFF
# 223        1     PAIDOFF
# 224        0     PAIDOFF
# 225        1     PAIDOFF
# 226        0     PAIDOFF
# 227        0     PAIDOFF
# 228        0     PAIDOFF
# 229        0     PAIDOFF
# 230        0     PAIDOFF
# 231        1     PAIDOFF
# 232        0     PAIDOFF
# 233        1     PAIDOFF
# 234        1     PAIDOFF
# 235        0     PAIDOFF
# 236        0     PAIDOFF
# 237        1     PAIDOFF
# 238        0     PAIDOFF
# 239        1     PAIDOFF
# 240        1     PAIDOFF
# 241        1     PAIDOFF
# 242        0     PAIDOFF
# 243        0     PAIDOFF
# 244        1     PAIDOFF
# 245        0     PAIDOFF
# 246        0     PAIDOFF
# 247        0     PAIDOFF
# 248        1     PAIDOFF
# 249        0     PAIDOFF
# 250        0     PAIDOFF
# 251        1     PAIDOFF
# 252        0     PAIDOFF
# 253        1     PAIDOFF
# 254        0     PAIDOFF
# 255        0     PAIDOFF
# 256        1     PAIDOFF
# 257        0     PAIDOFF
# 258        0     PAIDOFF
# 259        1     PAIDOFF
# 260        1  COLLECTION
# 261        0  COLLECTION
# 262        1  COLLECTION
# 263        0  COLLECTION
# 264        1  COLLECTION
# 265        0  COLLECTION
# 266        1  COLLECTION
# 267        0  COLLECTION
# 268        1  COLLECTION
# 269        0  COLLECTION
# 270        0  COLLECTION
# 271        0  COLLECTION
# 272        0  COLLECTION
# 273        1  COLLECTION
# 274        0  COLLECTION
# 275        1  COLLECTION
# 276        1  COLLECTION
# 277        1  COLLECTION
# 278        0  COLLECTION
# 279        0  COLLECTION
# 280        1  COLLECTION
# 281        0  COLLECTION
# 282        1  COLLECTION
# 283        0  COLLECTION
# 284        0  COLLECTION
# 285        1  COLLECTION
# 286        0  COLLECTION
# 287        1  COLLECTION
# 288        0  COLLECTION
# 289        1  COLLECTION
# 290        0  COLLECTION
# 291        0  COLLECTION
# 292        1  COLLECTION
# 293        0  COLLECTION
# 294        0  COLLECTION
# 295        0  COLLECTION
# 296        0  COLLECTION
# 297        0  COLLECTION
# 298        1  COLLECTION
# 299        0  COLLECTION
# 300        1  COLLECTION
# 301        0  COLLECTION
# 302        0  COLLECTION
# 303        0  COLLECTION
# 304        1  COLLECTION
# 305        0  COLLECTION
# 306        0  COLLECTION
# 307        1  COLLECTION
# 308        0  COLLECTION
# 309        1  COLLECTION
# 310        0  COLLECTION
# 311        0  COLLECTION
# 312        1  COLLECTION
# 313        1  COLLECTION
# 314        0  COLLECTION
# 315        0  COLLECTION
# 316        0  COLLECTION
# 317        1  COLLECTION
# 318        1  COLLECTION
# 319        0  COLLECTION
# 320        0  COLLECTION
# 321        1  COLLECTION
# 322        0  COLLECTION
# 323        1  COLLECTION
# 324        1  COLLECTION
# 325        1  COLLECTION
# 326        1  COLLECTION
# 327        0  COLLECTION
# 328        0  COLLECTION
# 329        0  COLLECTION
# 330        0  COLLECTION
# 331        0  COLLECTION
# 332        0  COLLECTION
# 333        0  COLLECTION
# 334        0  COLLECTION
# 335        0  COLLECTION
# 336        0  COLLECTION
# 337        1  COLLECTION
# 338        0  COLLECTION
# 339        1  COLLECTION
# 340        1  COLLECTION
# 341        0  COLLECTION
# 342        0  COLLECTION
# 343        1  COLLECTION
# 344        1  COLLECTION
# 345        1  COLLECTION

# %%
#new_df.to_csv("loancleaned.csv",index=False)

# %% [markdown]
# ## Normalize Data

# %% [markdown]
# Data Standardization give data zero mean and unit variance (technically should be done after train test split )

# %%
X = preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]
# Out:
# array([[ 0.51578458,  0.92071769,  2.33152555, -0.42056004, -1.20577805,
#         -0.38170062,  1.13639374, -0.86968108],
#        [ 0.51578458,  0.92071769,  0.34170148,  2.37778177, -1.20577805,
#          2.61985426, -0.87997669, -0.86968108],
#        [ 0.51578458, -0.95911111, -0.65321055, -0.42056004, -1.20577805,
#         -0.38170062, -0.87997669,  1.14984679],
#        [ 0.51578458,  0.92071769, -0.48739188,  2.37778177,  0.82934003,
#         -0.38170062, -0.87997669,  1.14984679],
#        [ 0.51578458,  0.92071769, -0.3215732 , -0.42056004,  0.82934003,
#         -0.38170062, -0.87997669,  1.14984679]])

# %% [markdown]
# # Classification

# %% [markdown]
# Now, it is your turn, use the training set to build an accurate model. Then use the test set to report the accuracy of the model
# You should use the following algorithm:
# - K Nearest Neighbor(KNN)
# - Decision Tree
# - Support Vector Machine
# - Logistic Regression
#
#
#
# __ Notice:__
# - You can go above and change the pre-processing, feature selection, feature-extraction, and so on, to make a better model.
# - You should use either scikit-learn, Scipy or Numpy libraries for developing the classification algorithms.
# - You should include the code of the algorithm in the following cells.

# %% [markdown]
# ## Split the data

# %%
X.shape
# Out:
# (346, 8)

# %%
y.shape
# Out:
# (346,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %%
X_train.shape
# Out:
# (276, 8)

# %%
X_test.shape
# Out:
# (70, 8)

# %%
y_train.shape
# Out:
# (276,)

# %%
y_test.shape
# Out:
# (70,)

# %% [markdown]
# # K Nearest Neighbor(KNN)
# Notice: You should find the best k to build the model with the best accuracy.
# **warning:** You should not use the __loan_test.csv__ for finding the best k, however, you can split your train_loan.csv into train and test to find the best __k__.

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# #### Comment: N_neighbours are K values.

# %% [markdown]
# ### Choosing K value

# %%
for i in range(1,20):
    knn = KNeighborsClassifier(n_neighbors=i)
    modelknn = knn.fit(X_train,y_train)
    predknn = modelknn.predict(X_test)
    m = accuracy_score(y_test,predknn)
    
    print(i)
    print(m)
# Out:
# 1
# 0.7142857142857143
# 2
# 0.6571428571428571
# 3
# 0.7714285714285715
# 4
# 0.7428571428571429
# 5
# 0.8
# 6
# 0.7428571428571429
# 7
# 0.7428571428571429
# 8
# 0.7142857142857143
# 9
# 0.7571428571428571
# 10
# 0.7285714285714285
# 11
# 0.7285714285714285
# 12
# 0.7
# 13
# 0.7142857142857143
# 14
# 0.7428571428571429
# 15
# 0.7571428571428571
# 16
# 0.7571428571428571
# 17
# 0.7428571428571429
# 18
# 0.7142857142857143
# 19
# 0.7142857142857143

# %% [markdown]
# #### Choose K=5 for best accuracy

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predknn = knn.predict(X_test)

# %%
y_predknn   # y(knn) predictions in an array
# Out:
# array(['PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'COLLECTION', 'PAIDOFF', 'PAIDOFF', 'COLLECTION',
#        'COLLECTION', 'COLLECTION', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'COLLECTION', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'COLLECTION',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'COLLECTION', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'COLLECTION', 'COLLECTION', 'COLLECTION', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'COLLECTION', 'PAIDOFF'],
#       dtype=object)

# %%
cmknn = confusion_matrix(y_test,y_predknn)

# %%
print(cmknn)
# Out:
# [[ 7 10]
#  [ 4 49]]

# %%
print(classification_report(y_test,y_predknn))
# Out:
#               precision    recall  f1-score   support
#
#   COLLECTION       0.64      0.41      0.50        17
#      PAIDOFF       0.83      0.92      0.88        53
#
#     accuracy                           0.80        70
#    macro avg       0.73      0.67      0.69        70
# weighted avg       0.78      0.80      0.78        70

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier(criterion='entropy', random_state=1234)

# %%
tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=1234)

# %%
tree.feature_importances_   #age and weekend features affect the prediction
# Out:
# array([0.1165207 , 0.12591358, 0.31941557, 0.04668837, 0.33130697,
#        0.02126574, 0.02893401, 0.00995506])

# %%
y_predtree = tree.predict(X_test)

# %%
treecm = confusion_matrix(y_test,y_predtree)

# %%
print(treecm)
# Out:
# [[ 9  8]
#  [14 39]]

# %%
print(classification_report(y_test,y_predtree))
# Out:
#               precision    recall  f1-score   support
#
#   COLLECTION       0.39      0.53      0.45        17
#      PAIDOFF       0.83      0.74      0.78        53
#
#     accuracy                           0.69        70
#    macro avg       0.61      0.63      0.61        70
# weighted avg       0.72      0.69      0.70        70

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
svm = SVC(random_state=1234, gamma='auto')

# %%
svm.fit(X_train,y_train)
# Out:
# SVC(gamma='auto', random_state=1234)

# %%
y_predsvm = svm.predict(X_test)

# %%
svmcm = confusion_matrix(y_test,y_predsvm)

# %%
print(svmcm)
# Out:
# [[ 1 16]
#  [ 1 52]]

# %%
print(classification_report(y_test,y_predsvm))
# Out:
#               precision    recall  f1-score   support
#
#   COLLECTION       0.50      0.06      0.11        17
#      PAIDOFF       0.76      0.98      0.86        53
#
#     accuracy                           0.76        70
#    macro avg       0.63      0.52      0.48        70
# weighted avg       0.70      0.76      0.68        70

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logic = LogisticRegression(C=0.01, solver='lbfgs',random_state=1234)

# %%
logic.fit(X_train,y_train)
# Out:
# LogisticRegression(C=0.01, random_state=1234)

# %%
y_predlogic = logic.predict(X_test)

# %%
logiccm = confusion_matrix(y_test,y_predlogic)

# %%
print(logiccm)
# Out:
# [[ 0 17]
#  [ 0 53]]

# %%
print(classification_report(y_test,y_predlogic))
# Out:
#               precision    recall  f1-score   support
#
#   COLLECTION       0.00      0.00      0.00        17
#      PAIDOFF       0.76      1.00      0.86        53
#
#     accuracy                           0.76        70
#    macro avg       0.38      0.50      0.43        70
# weighted avg       0.57      0.76      0.65        70

# %% [markdown]
# ### Note these are trained models scoring, need to feed in test set to check

# %% [markdown]
# # Model Evaluation using Test set

# %%
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss

# %%
def jaccard_index(predictions, true):
    if (len(predictions) == len(true)):
        intersect = 0;
        for x,y in zip(predictions, true):
            if (x == y):
                intersect += 1
        return intersect / (len(predictions) + len(true) - intersect)
    else:
        return -1

# %% [markdown]
# First, download and load the test set:

# %%
#!wget -O loan_test.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_test.csv

# %% [markdown]
# ### Load Test set for evaluation

# %%
test_df = pd.read_csv('loantest.csv')
test_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           1             1     PAIDOFF       1000     30       9/8/2016
# 1           5             5     PAIDOFF        300      7       9/9/2016
# 2          21            21     PAIDOFF       1000     30      9/10/2016
# 3          24            24     PAIDOFF       1000     30      9/10/2016
# 4          35            35     PAIDOFF        800     15      9/11/2016
#
#     due_date  age             education  Gender
# 0  10/7/2016   50              Bechalor  female
# 1  9/15/2016   35       Master or Above    male
# 2  10/9/2016   43  High School or Below  female
# 3  10/9/2016   26               college    male
# 4  9/25/2016   29              Bechalor    male

# %%
test_df['due_date'] = pd.to_datetime(df['due_date'])
test_df['effective_date'] = pd.to_datetime(df['effective_date'])
test_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           1             1     PAIDOFF       1000     30     2016-09-08
# 1           5             5     PAIDOFF        300      7     2016-09-08
# 2          21            21     PAIDOFF       1000     30     2016-09-08
# 3          24            24     PAIDOFF       1000     30     2016-09-09
# 4          35            35     PAIDOFF        800     15     2016-09-09
#
#     due_date  age             education  Gender
# 0 2016-10-07   50              Bechalor  female
# 1 2016-10-07   35       Master or Above    male
# 2 2016-09-22   43  High School or Below  female
# 3 2016-10-08   26               college    male
# 4 2016-10-08   29              Bechalor    male

# %%
test_df['dayofweek'] = test_df['effective_date'].dt.dayofweek

# %%
test_df['weekend'] = df['dayofweek'].apply(lambda x: 1 if (x>3)  else 0)
test_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           1             1     PAIDOFF       1000     30     2016-09-08
# 1           5             5     PAIDOFF        300      7     2016-09-08
# 2          21            21     PAIDOFF       1000     30     2016-09-08
# 3          24            24     PAIDOFF       1000     30     2016-09-09
# 4          35            35     PAIDOFF        800     15     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   50              Bechalor  female          3        0
# 1 2016-10-07   35       Master or Above    male          3        0
# 2 2016-09-22   43  High School or Below  female          3        0
# 3 2016-10-08   26               college    male          4        1
# 4 2016-10-08   29              Bechalor    male          4        1

# %%
test_df['Gender'].replace(to_replace=['male','female'], value=[0,1],inplace=True)
test_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           1             1     PAIDOFF       1000     30     2016-09-08
# 1           5             5     PAIDOFF        300      7     2016-09-08
# 2          21            21     PAIDOFF       1000     30     2016-09-08
# 3          24            24     PAIDOFF       1000     30     2016-09-09
# 4          35            35     PAIDOFF        800     15     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   50              Bechalor       1          3        0
# 1 2016-10-07   35       Master or Above       0          3        0
# 2 2016-09-22   43  High School or Below       1          3        0
# 3 2016-10-08   26               college       0          4        1
# 4 2016-10-08   29              Bechalor       0          4        1

# %%
testset = test_df[['Principal','terms','age','Gender','weekend']]
testset = pd.concat([testset,pd.get_dummies(test_df['education'])], axis=1)
testset.drop(['Master or Above'], axis = 1,inplace=True)
testset.head()
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   50       1        0         1                     0
# 1        300      7   35       0        0         0                     0
# 2       1000     30   43       1        0         0                     1
# 3       1000     30   26       0        1         0                     0
# 4        800     15   29       0        1         1                     0
#
#    college
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0

# %%
Xtest = testset  #Define X Test Set
Xtest[0:5]
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   50       1        0         1                     0
# 1        300      7   35       0        0         0                     0
# 2       1000     30   43       1        0         0                     1
# 3       1000     30   26       0        1         0                     0
# 4        800     15   29       0        1         1                     0
#
#    college
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0

# %%
#Normalise data first
Xtest= preprocessing.StandardScaler().fit(Xtest).transform(Xtest)
Xtest[0:5]
# Out:
# array([[ 0.49362588,  0.92844966,  3.05981865,  1.97714211, -4.12310563,
#          2.39791576, -0.79772404, -0.86135677],
#        [-3.56269116, -1.70427745,  0.53336288, -0.50578054, -4.12310563,
#         -0.41702883, -0.79772404, -0.86135677],
#        [ 0.49362588,  0.92844966,  1.88080596,  1.97714211, -4.12310563,
#         -0.41702883,  1.25356634, -0.86135677],
#        [ 0.49362588,  0.92844966, -0.98251057, -0.50578054,  0.24253563,
#         -0.41702883, -0.79772404,  1.16095912],
#        [-0.66532184, -0.78854628, -0.47721942, -0.50578054,  0.24253563,
#          2.39791576, -0.79772404, -0.86135677]])

# %%
ytest = test_df['loan_status'] #Define y Test Set

# %%
ytest.head()
# Out:
# 0    PAIDOFF
# 1    PAIDOFF
# 2    PAIDOFF
# 3    PAIDOFF
# 4    PAIDOFF
# Name: loan_status, dtype: object

# %%
Xtest.shape
# Out:
# (54, 8)

# %%
ytest.shape
# Out:
# (54,)

# %% [markdown]
# ### Using KNN Model

# %%
yptknn = knn.predict(Xtest)

# %%
print(classification_report(ytest,yptknn))
# Out:
#               precision    recall  f1-score   support
#
#   COLLECTION       0.30      0.21      0.25        14
#      PAIDOFF       0.75      0.82      0.79        40
#
#     accuracy                           0.67        54
#    macro avg       0.53      0.52      0.52        54
# weighted avg       0.63      0.67      0.65        54

# %%
print("KNN Jaccard Index Score %.2f" %jaccard_index(yptknn,ytest))
# Out:
# KNN Jaccard Index Score 0.50

# %%
print("KNN f1 score %.2f" % f1_score(ytest,yptknn, average='weighted'))
# Out:
# KNN f1 score 0.65

# %% [markdown]
# ### Using Decision Tree Model

# %%
ypttree = tree.predict(Xtest)

# %%
print(classification_report(ytest,ypttree))
# Out:
#               precision    recall  f1-score   support
#
#   COLLECTION       0.32      0.57      0.41        14
#      PAIDOFF       0.79      0.57      0.67        40
#
#     accuracy                           0.57        54
#    macro avg       0.56      0.57      0.54        54
# weighted avg       0.67      0.57      0.60        54

# %%
print("DT Jaccard Index Score %.2f" % jaccard_index(ypttree,ytest))
# Out:
# DT Jaccard Index Score 0.40

# %%
print("DT f1 score %.2f" % f1_score(ytest,ypttree, average='weighted'))
# Out:
# DT f1 score 0.60

# %% [markdown]
# ### Using SVM Model

# %%
yptsvm = svm.predict(Xtest)

# %%
print(classification_report(ytest,yptsvm))
# Out:
#               precision    recall  f1-score   support
#
#   COLLECTION       0.00      0.00      0.00        14
#      PAIDOFF       0.74      1.00      0.85        40
#
#     accuracy                           0.74        54
#    macro avg       0.37      0.50      0.43        54
# weighted avg       0.55      0.74      0.63        54

# %%
print("SVM Jaccard Index Score %.2f" % jaccard_index(yptsvm,ytest))
# Out:
# SVM Jaccard Index Score 0.59

# %%
print("SVM f1 score %.2f" % f1_score(ytest,yptsvm, average='weighted'))
# Out:
# SVM f1 score 0.63

# %% [markdown]
# ### Using Logistic Regression Model

# %%
ytlogic = logic.predict(Xtest)

# %%
ytlogicprob = logic.predict_proba(Xtest)

# %%
print(classification_report(ytest,ytlogic))
# Out:
#               precision    recall  f1-score   support
#
#   COLLECTION       0.00      0.00      0.00        14
#      PAIDOFF       0.74      1.00      0.85        40
#
#     accuracy                           0.74        54
#    macro avg       0.37      0.50      0.43        54
# weighted avg       0.55      0.74      0.63        54

# %%
print("Logistic Jaccard Index Score %.2f" % jaccard_index(ytlogic,ytest))
# Out:
# Logistic Jaccard Index Score 0.59

# %%
print("Logistic f1 score %.2f" % f1_score(ytest,ytlogic, average='weighted'))
# Out:
# Logistic f1 score 0.63

# %%
print("Logistic LogLoss: %.2f" % log_loss(ytest, ytlogicprob))
# Out:
# Logistic LogLoss: 0.55

# %% [markdown]
# # Report
# You should be able to report the accuracy of the built model using different evaluation metrics:

# %% [markdown]
# | Algorithm          | Jaccard | F1-score | LogLoss |
# |--------------------|---------|----------|---------|
# | KNN                | 0.50    | 0.65     | NA      |
# | Decision Tree      | 0.40    | 0.60     | NA      |
# | SVM                | 0.59    | 0.63     | NA      |
# | LogisticRegression | 0.59    | 0.63     | 0.55    |

# %% [markdown]
# ## PyCaret Model

# %%
new_df.head()
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college loan_status
# 0        0     PAIDOFF
# 1        0     PAIDOFF
# 2        1     PAIDOFF
# 3        1     PAIDOFF
# 4        1     PAIDOFF

# %%
new_df.columns
# Out:
# Index(['Principal', 'terms', 'age', 'Gender', 'weekend', 'Bechalor',
#        'High School or Below', 'college', 'loan_status'],
#       dtype='object')

# %%
exp_clf101 = setup(data = new_df, target = 'loan_status', session_id=1234, train_size=0.8,
          categorical_features=['Gender', 'weekend', 'Bechalor','High School or Below', 'college'],
            numeric_features=['Principal', 'terms', 'age'])
# Out:
# <style  type="text/css" >
# </style><table id="T_5e343040_2718_11eb_8e1f_3c528213d836" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row0_col1" class="data row0 col1" >1234</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row1_col1" class="data row1 col1" >loan_status</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row3_col1" class="data row3 col1" >COLLECTION: 0, PAIDOFF: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row4_col1" class="data row4 col1" >(346, 9)</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row6_col1" class="data row6 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row7_col1" class="data row7 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row11_col1" class="data row11 col1" >(276, 8)</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row12_col1" class="data row12 col1" >(70, 8)</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_5e343040_2718_11eb_8e1f_3c528213d836level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_5e343040_2718_11eb_8e1f_3c528213d836row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>

# %%
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_6bbe7560_2718_11eb_89b2_3c528213d836 th {
#           text-align: left;
#     }#T_6bbe7560_2718_11eb_89b2_3c528213d836row0_col0,#T_6bbe7560_2718_11eb_89b2_3c528213d836row0_col2,#T_6bbe7560_2718_11eb_89b2_3c528213d836row0_col3,#T_6bbe7560_2718_11eb_89b2_3c528213d836row0_col4,#T_6bbe7560_2718_11eb_89b2_3c528213d836row0_col5,#T_6bbe7560_2718_11eb_89b2_3c528213d836row0_col6,#T_6bbe7560_2718_11eb_89b2_3c528213d836row0_col7,#T_6bbe7560_2718_11eb_89b2_3c528213d836row1_col0,#T_6bbe7560_2718_11eb_89b2_3c528213d836row1_col1,#T_6bbe7560_2718_11eb_89b2_3c528213d836row1_col2,#T_6bbe7560_2718_11eb_89b2_3c528213d836row1_col3,#T_6bbe7560_2718_11eb_89b2_3c528213d836row1_col4,#T_6bbe7560_2718_11eb_89b2_3c528213d836row1_col5,#T_6bbe7560_2718_11eb_89b2_3c528213d836row1_col6,#T_6bbe7560_2718_11eb_89b2_3c528213d836row1_col7,#T_6bbe7560_2718_11eb_89b2_3c528213d836row2_col0,#T_6bbe7560_2718_11eb_89b2_3c528213d836row2_col1,#T_6bbe7560_2718_11eb_89b2_3c528213d836row2_col2,#T_6bbe7560_2718_11eb_89b2_3c528213d836row2_col3,#T_6bbe7560_2718_11eb_89b2_3c528213d836row2_col4,#T_6bbe7560_2718_11eb_89b2_3c528213d836row2_col5,#T_6bbe7560_2718_11eb_89b2_3c528213d836row2_col6,#T_6bbe7560_2718_11eb_89b2_3c528213d836row2_col7,#T_6bbe7560_2718_11eb_89b2_3c528213d836row3_col0,#T_6bbe7560_2718_11eb_89b2_3c528213d836row3_col1,#T_6bbe7560_2718_11eb_89b2_3c528213d836row3_col2,#T_6bbe7560_2718_11eb_89b2_3c528213d836row3_col3,#T_6bbe7560_2718_11eb_89b2_3c528213d836row3_col4,#T_6bbe7560_2718_11eb_89b2_3c528213d836row3_col5,#T_6bbe7560_2718_11eb_89b2_3c528213d836row3_col6,#T_6bbe7560_2718_11eb_89b2_3c528213d836row3_col7,#T_6bbe7560_2718_11eb_89b2_3c528213d836row4_col0,#T_6bbe7560_2718_11eb_89b2_3c528213d836row4_col1,#T_6bbe7560_2718_11eb_89b2_3c528213d836row4_col2,#T_6bbe7560_2718_11eb_89b2_3c528213d836row4_col3,#T_6bbe7560_2718_11eb_89b2_3c528213d836row4_col4,#T_6bbe7560_2718_11eb_89b2_3c528213d836row4_col5,#T_6bbe7560_2718_11eb_89b2_3c528213d836row4_col6,#T_6bbe7560_2718_11eb_89b2_3c528213d836row4_col7,#T_6bbe7560_2718_11eb_89b2_3c528213d836row5_col0,#T_6bbe7560_2718_11eb_89b2_3c528213d836row5_col1,#T_6bbe7560_2718_11eb_89b2_3c528213d836row6_col0,#T_6bbe7560_2718_11eb_89b2_3c528213d836row6_col1,#T_6bbe7560_2718_11eb_89b2_3c528213d836row6_col2,#T_6bbe7560_2718_11eb_89b2_3c528213d836row6_col3,#T_6bbe7560_2718_11eb_89b2_3c528213d836row6_col4,#T_6bbe7560_2718_11eb_89b2_3c528213d836row6_col5,#T_6bbe7560_2718_11eb_89b2_3c528213d836row6_col6,#T_6bbe7560_2718_11eb_89b2_3c528213d836row6_col7,#T_6bbe7560_2718_11eb_89b2_3c528213d836row7_col0,#T_6bbe7560_2718_11eb_89b2_3c528213d836row7_col1,#T_6bbe7560_2718_11eb_89b2_3c528213d836row7_col2,#T_6bbe7560_2718_11eb_89b2_3c528213d836row7_col3,#T_6bbe7560_2718_11eb_89b2_3c528213d836row7_col4,#T_6bbe7560_2718_11eb_89b2_3c528213d836row7_col5,#T_6bbe7560_2718_11eb_89b2_3c528213d836row7_col6,#T_6bbe7560_2718_11eb_89b2_3c528213d836row7_col7,#T_6bbe7560_2718_11eb_89b2_3c528213d836row8_col0,#T_6bbe7560_2718_11eb_89b2_3c528213d836row8_col1,#T_6bbe7560_2718_11eb_89b2_3c528213d836row8_col2,#T_6bbe7560_2718_11eb_89b2_3c528213d836row8_col3,#T_6bbe7560_2718_11eb_89b2_3c528213d836row8_col4,#T_6bbe7560_2718_11eb_89b2_3c528213d836row8_col5,#T_6bbe7560_2718_11eb_89b2_3c528213d836row8_col6,#T_6bbe7560_2718_11eb_89b2_3c528213d836row8_col7,#T_6bbe7560_2718_11eb_89b2_3c528213d836row9_col0,#T_6bbe7560_2718_11eb_89b2_3c528213d836row9_col1,#T_6bbe7560_2718_11eb_89b2_3c528213d836row9_col2,#T_6bbe7560_2718_11eb_89b2_3c528213d836row9_col3,#T_6bbe7560_2718_11eb_89b2_3c528213d836row9_col4,#T_6bbe7560_2718_11eb_89b2_3c528213d836row9_col5,#T_6bbe7560_2718_11eb_89b2_3c528213d836row9_col6,#T_6bbe7560_2718_11eb_89b2_3c528213d836row9_col7,#T_6bbe7560_2718_11eb_89b2_3c528213d836row10_col0,#T_6bbe7560_2718_11eb_89b2_3c528213d836row10_col1,#T_6bbe7560_2718_11eb_89b2_3c528213d836row10_col2,#T_6bbe7560_2718_11eb_89b2_3c528213d836row10_col3,#T_6bbe7560_2718_11eb_89b2_3c528213d836row10_col4,#T_6bbe7560_2718_11eb_89b2_3c528213d836row10_col5,#T_6bbe7560_2718_11eb_89b2_3c528213d836row10_col6,#T_6bbe7560_2718_11eb_89b2_3c528213d836row10_col7,#T_6bbe7560_2718_1 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_6bbe7560_2718_11eb_89b2_3c528213d836row0_col1,#T_6bbe7560_2718_11eb_89b2_3c528213d836row5_col2,#T_6bbe7560_2718_11eb_89b2_3c528213d836row5_col3,#T_6bbe7560_2718_11eb_89b2_3c528213d836row5_col4,#T_6bbe7560_2718_11eb_89b2_3c528213d836row5_col5,#T_6bbe7560_2718_11eb_89b2_3c528213d836row5_col6,#T_6bbe7560_2718_11eb_89b2_3c528213d836row5_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_6bbe7560_2718_11eb_89b2_3c528213d836row0_col8,#T_6bbe7560_2718_11eb_89b2_3c528213d836row1_col8,#T_6bbe7560_2718_11eb_89b2_3c528213d836row3_col8,#T_6bbe7560_2718_11eb_89b2_3c528213d836row4_col8,#T_6bbe7560_2718_11eb_89b2_3c528213d836row5_col8,#T_6bbe7560_2718_11eb_89b2_3c528213d836row6_col8,#T_6bbe7560_2718_11eb_89b2_3c528213d836row7_col8,#T_6bbe7560_2718_11eb_89b2_3c528213d836row8_col8,#T_6bbe7560_2718_11eb_89b2_3c528213d836row9_col8,#T_6bbe7560_2718_11eb_89b2_3c528213d836row10_col8,#T_6bbe7560_2718_11eb_89b2_3c528213d836row12_col8,#T_6bbe7560_2718_11eb_89b2_3c528213d836row13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_6bbe7560_2718_11eb_89b2_3c528213d836row2_col8,#T_6bbe7560_2718_11eb_89b2_3c528213d836row11_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_6bbe7560_2718_11eb_89b2_3c528213d836" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6bbe7560_2718_11eb_89b2_3c528213d836level0_row0" class="row_heading level0 row0" >lr</th>
#                         <td id="T_6bbe7560_2718_11eb_89b2_3c528213d836row0_col0" class="data row0 col0" >Logistic Regression</td>
#                         <td id="T_6bbe7560_2718_11eb_89b2_3c528213d836row0_col1" class="data row0 col1" >0.7430</td>
#                         <td id="T_6bbe7560_2718_11eb_89b2_3c528213d836row0_col2" class="data row0 col2" >0.7766</td>
#                         <td id="T_6bbe7560_2718_11eb_89b2_3c528213d836row0_col3" class="d

# %%
print(best_model)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=1234, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lr = create_model('lr')
# Out:
# <style  type="text/css" >
# #T_6c0cc523_2718_11eb_aac4_3c528213d836row10_col0,#T_6c0cc523_2718_11eb_aac4_3c528213d836row10_col1,#T_6c0cc523_2718_11eb_aac4_3c528213d836row10_col2,#T_6c0cc523_2718_11eb_aac4_3c528213d836row10_col3,#T_6c0cc523_2718_11eb_aac4_3c528213d836row10_col4,#T_6c0cc523_2718_11eb_aac4_3c528213d836row10_col5,#T_6c0cc523_2718_11eb_aac4_3c528213d836row10_col6{
#             background:  yellow;
#         }</style><table id="T_6c0cc523_2718_11eb_aac4_3c528213d836" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6c0cc523_2718_11eb_aac4_3c528213d836level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row0_col0" class="data row0 col0" >0.7500</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row0_col1" class="data row0 col1" >0.7789</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row0_col2" class="data row0 col2" >0.6429</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row0_col3" class="data row0 col3" >0.7386</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row0_col4" class="data row0 col4" >0.7433</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row0_col5" class="data row0 col5" >0.3000</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row0_col6" class="data row0 col6" >0.3015</td>
#             </tr>
#             <tr>
#                         <th id="T_6c0cc523_2718_11eb_aac4_3c528213d836level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row1_col0" class="data row1 col0" >0.8214</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row1_col1" class="data row1 col1" >0.8095</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row1_col2" class="data row1 col2" >0.6429</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row1_col3" class="data row1 col3" >0.8558</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row1_col4" class="data row1 col4" >0.7813</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row1_col5" class="data row1 col5" >0.3750</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row1_col6" class="data row1 col6" >0.4804</td>
#             </tr>
#             <tr>
#                         <th id="T_6c0cc523_2718_11eb_aac4_3c528213d836level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row2_col0" class="data row2 col0" >0.6786</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row2_col1" class="data row2 col1" >0.7279</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row2_col2" class="data row2 col2" >0.4524</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row2_col3" class="data row2 col3" >0.5481</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row2_col4" class="data row2 col4" >0.6064</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row2_col5" class="data row2 col5" >-0.1250</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row2_col6" class="data row2 col6" >-0.1601</td>
#             </tr>
#             <tr>
#                         <th id="T_6c0cc523_2718_11eb_aac4_3c528213d836level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row3_col0" class="data row3 col0" >0.6429</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row3_col1" class="data row3 col1" >0.7551</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row3_col2" class="data row3 col2" >0.4286</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row3_col3" class="data row3 col3" >0.5400</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row3_col4" class="data row3 col4" >0.5870</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row3_col5" class="data row3 col5" >-0.1765</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row3_col6" class="data row3 col6" >-0.2000</td>
#             </tr>
#             <tr>
#                         <th id="T_6c0cc523_2718_11eb_aac4_3c528213d836level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row4_col0" class="data row4 col0" >0.7500</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row4_col1" class="data row4 col1" >0.8231</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row4_col2" class="data row4 col2" >0.5000</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row4_col3" class="data row4 col3" >0.5625</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row4_col4" class="data row4 col4" >0.6429</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row4_col5" class="data row4 col5" >0.0000</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row4_col6" class="data row4 col6" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_6c0cc523_2718_11eb_aac4_3c528213d836level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row5_col0" class="data row5 col0" >0.7500</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row5_col1" class="data row5 col1" >0.7279</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row5_col2" class="data row5 col2" >0.5000</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row5_col3" class="data row5 col3" >0.5625</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row5_col4" class="data row5 col4" >0.6429</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row5_col5" class="data row5 col5" >0.0000</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row5_col6" class="data row5 col6" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_6c0cc523_2718_11eb_aac4_3c528213d836level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row6_col0" class="data row6 col0" >0.7778</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row6_col1" class="data row6 col1" >0.8333</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row6_col2" class="data row6 col2" >0.6786</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row6_col3" class="data row6 col3" >0.7778</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row6_col4" class="data row6 col4" >0.7778</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row6_col5" class="data row6 col5" >0.3571</td>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row6_col6" class="data row6 col6" >0.3571</td>
#             </tr>
#             <tr>
#                         <th id="T_6c0cc523_2718_11eb_aac4_3c528213d836level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_6c0cc523_2718_11eb_aac4_3c528213d836row

# %%
tuned_lr = tune_model(lr)
# Out:
# <style  type="text/css" >
# #T_6d6b55e9_2718_11eb_b876_3c528213d836row10_col0,#T_6d6b55e9_2718_11eb_b876_3c528213d836row10_col1,#T_6d6b55e9_2718_11eb_b876_3c528213d836row10_col2,#T_6d6b55e9_2718_11eb_b876_3c528213d836row10_col3,#T_6d6b55e9_2718_11eb_b876_3c528213d836row10_col4,#T_6d6b55e9_2718_11eb_b876_3c528213d836row10_col5,#T_6d6b55e9_2718_11eb_b876_3c528213d836row10_col6{
#             background:  yellow;
#         }</style><table id="T_6d6b55e9_2718_11eb_b876_3c528213d836" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6d6b55e9_2718_11eb_b876_3c528213d836level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row0_col0" class="data row0 col0" >0.7143</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row0_col1" class="data row0 col1" >0.7789</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row0_col2" class="data row0 col2" >0.6190</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row0_col3" class="data row0 col3" >0.7143</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row0_col4" class="data row0 col4" >0.7143</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row0_col5" class="data row0 col5" >0.2381</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row0_col6" class="data row0 col6" >0.2381</td>
#             </tr>
#             <tr>
#                         <th id="T_6d6b55e9_2718_11eb_b876_3c528213d836level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row1_col0" class="data row1 col0" >0.8214</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row1_col1" class="data row1 col1" >0.8027</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row1_col2" class="data row1 col2" >0.6429</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row1_col3" class="data row1 col3" >0.8558</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row1_col4" class="data row1 col4" >0.7813</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row1_col5" class="data row1 col5" >0.3750</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row1_col6" class="data row1 col6" >0.4804</td>
#             </tr>
#             <tr>
#                         <th id="T_6d6b55e9_2718_11eb_b876_3c528213d836level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row2_col0" class="data row2 col0" >0.6786</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row2_col1" class="data row2 col1" >0.7483</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row2_col2" class="data row2 col2" >0.5000</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row2_col3" class="data row2 col3" >0.6250</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row2_col4" class="data row2 col4" >0.6455</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row2_col5" class="data row2 col5" >0.0000</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row2_col6" class="data row2 col6" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_6d6b55e9_2718_11eb_b876_3c528213d836level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row3_col0" class="data row3 col0" >0.6429</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row3_col1" class="data row3 col1" >0.7483</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row3_col2" class="data row3 col2" >0.4286</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row3_col3" class="data row3 col3" >0.5400</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row3_col4" class="data row3 col4" >0.5870</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row3_col5" class="data row3 col5" >-0.1765</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row3_col6" class="data row3 col6" >-0.2000</td>
#             </tr>
#             <tr>
#                         <th id="T_6d6b55e9_2718_11eb_b876_3c528213d836level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row4_col0" class="data row4 col0" >0.7857</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row4_col1" class="data row4 col1" >0.7891</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row4_col2" class="data row4 col2" >0.5714</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row4_col3" class="data row4 col3" >0.8333</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row4_col4" class="data row4 col4" >0.7188</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row4_col5" class="data row4 col5" >0.2000</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row4_col6" class="data row4 col6" >0.3333</td>
#             </tr>
#             <tr>
#                         <th id="T_6d6b55e9_2718_11eb_b876_3c528213d836level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row5_col0" class="data row5 col0" >0.7500</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row5_col1" class="data row5 col1" >0.7211</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row5_col2" class="data row5 col2" >0.5476</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row5_col3" class="data row5 col3" >0.7019</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row5_col4" class="data row5 col4" >0.6939</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row5_col5" class="data row5 col5" >0.1250</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row5_col6" class="data row5 col6" >0.1601</td>
#             </tr>
#             <tr>
#                         <th id="T_6d6b55e9_2718_11eb_b876_3c528213d836level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row6_col0" class="data row6 col0" >0.7778</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row6_col1" class="data row6 col1" >0.8333</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row6_col2" class="data row6 col2" >0.6786</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row6_col3" class="data row6 col3" >0.7778</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row6_col4" class="data row6 col4" >0.7778</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row6_col5" class="data row6 col5" >0.3571</td>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row6_col6" class="data row6 col6" >0.3571</td>
#             </tr>
#             <tr>
#                         <th id="T_6d6b55e9_2718_11eb_b876_3c528213d836level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_6d6b55e9_2718_11eb_b876_3c528213d836row7_

# %%
print(tuned_lr)
# Out:
# LogisticRegression(C=5.926, class_weight={}, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=1234, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
plot_model(tuned_lr, plot = 'auc')

# %%
plot_model(tuned_lr, plot = 'pr')

# %%
plot_model(tuned_lr, plot='feature')

# %%
plot_model(tuned_lr, plot = 'confusion_matrix')

# %%
predict_model(tuned_lr)
# Out:
# <style  type="text/css" >
# </style><table id="T_6e6c873c_2718_11eb_b8ea_3c528213d836" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6e6c873c_2718_11eb_b8ea_3c528213d836level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6e6c873c_2718_11eb_b8ea_3c528213d836row0_col0" class="data row0 col0" >Logistic Regression</td>
#                         <td id="T_6e6c873c_2718_11eb_b8ea_3c528213d836row0_col1" class="data row0 col1" >0.7714</td>
#                         <td id="T_6e6c873c_2718_11eb_b8ea_3c528213d836row0_col2" class="data row0 col2" >0.7303</td>
#                         <td id="T_6e6c873c_2718_11eb_b8ea_3c528213d836row0_col3" class="data row0 col3" >0.5893</td>
#                         <td id="T_6e6c873c_2718_11eb_b8ea_3c528213d836row0_col4" class="data row0 col4" >0.7397</td>
#                         <td id="T_6e6c873c_2718_11eb_b8ea_3c528213d836row0_col5" class="data row0 col5" >0.7337</td>
#                         <td id="T_6e6c873c_2718_11eb_b8ea_3c528213d836row0_col6" class="data row0 col6" >0.2233</td>
#                         <td id="T_6e6c873c_2718_11eb_b8ea_3c528213d836row0_col7" class="data row0 col7" >0.2554</td>
#             </tr>
#     </tbody></table>
#     Principal  terms   age  Gender_1  weekend_0  Bechalor_0  \
# 0       800.0   15.0  36.0       0.0        1.0         1.0
# 1      1000.0   30.0  31.0       0.0        1.0         1.0
# 2      1000.0   30.0  20.0       0.0        0.0         1.0
# 3      1000.0   30.0  28.0       0.0        0.0         1.0
# 4      1000.0   15.0  24.0       1.0        0.0         0.0
# ..        ...    ...   ...       ...        ...         ...
# 65     1000.0   15.0  30.0       0.0        0.0         0.0
# 66     1000.0   30.0  38.0       0.0        0.0         0.0
# 67      800.0   15.0  40.0       0.0        0.0         1.0
# 68     1000.0   30.0  32.0       0.0        0.0         1.0
# 69     1000.0   30.0  24.0       0.0        1.0         1.0
#
#     High School or Below_0  college_0 loan_status       Label   Score
# 0                      0.0        1.0     PAIDOFF     PAIDOFF  0.9821
# 1                      1.0        0.0     PAIDOFF     PAIDOFF  0.9752
# 2                      0.0        1.0     PAIDOFF  COLLECTION  0.5884
# 3                      0.0        1.0     PAIDOFF  COLLECTION  0.5269
# 4                      1.0        1.0     PAIDOFF     PAIDOFF  0.6781
# ..                     ...        ...         ...         ...     ...
# 65                     1.0        1.0  COLLECTION     PAIDOFF  0.6140
# 66                     1.0        1.0     PAIDOFF     PAIDOFF  0.5737
# 67                     1.0        0.0  COLLECTION     PAIDOFF  0.7391
# 68                     1.0        0.0     PAIDOFF     PAIDOFF  0.5786
# 69                     1.0        0.0     PAIDOFF     PAIDOFF  0.9693
#
# [70 rows x 11 columns]

# %%
unseen_predictions = predict_model(tuned_lr, data=testset)
unseen_predictions.head()
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   50       1        0         1                     0
# 1        300      7   35       0        0         0                     0
# 2       1000     30   43       1        0         0                     1
# 3       1000     30   26       0        1         0                     0
# 4        800     15   29       0        1         1                     0
#
#    college    Label   Score
# 0        0  PAIDOFF  0.9893
# 1        0  PAIDOFF  0.9893
# 2        0  PAIDOFF  0.9855
# 3        1  PAIDOFF  0.5323
# 4        0  PAIDOFF  0.6203

# %% [markdown]
# <h2>Want to learn more?</h2>
#
# IBM SPSS Modeler is a comprehensive analytics platform that has many machine learning algorithms. It has been designed to bring predictive intelligence to decisions made by individuals, by groups, by systems – by your enterprise as a whole. A free trial is available through this course, available here: <a href="http://cocl.us/ML0101EN-SPSSModeler">SPSS Modeler</a>
#
# Also, you can use Watson Studio to run these notebooks faster with bigger datasets. Watson Studio is IBM's leading cloud solution for data scientists, built by data scientists. With Jupyter notebooks, RStudio, Apache Spark and popular libraries pre-packaged in the cloud, Watson Studio enables data scientists to collaborate on their projects without having to install anything. Join the fast-growing community of Watson Studio users today with a free account at <a href="https://cocl.us/ML0101EN_DSX">Watson Studio</a>
#
# <h3>Thanks for completing this lesson!</h3>
#
# <h4>Author:  <a href="https://ca.linkedin.com/in/saeedaghabozorgi">Saeed Aghabozorgi</a></h4>
# <p><a href="https://ca.linkedin.com/in/saeedaghabozorgi">Saeed Aghabozorgi</a>, PhD is a Data Scientist in IBM with a track record of developing enterprise level applications that substantially increases clients’ ability to turn data into actionable knowledge. He is a researcher in data mining field and expert in developing advanced analytic methods like machine learning and statistical modelling on large datasets.</p>
#
# <hr>
#
# <p>Copyright &copy; 2018 <a href="https://cocl.us/DX0108EN_CC">Cognitive Class</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/">MIT License</a>.</p>
